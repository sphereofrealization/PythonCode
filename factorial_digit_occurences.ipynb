# %%
from collections import Counter

def factorial(n):
    if n == 0 or n == 1:
        return 1
    fact = 1
    for i in range(2, n + 1):
        fact *= i
    return fact

def convert_to_base(n, base):
    if n == 0:
        return [0]
    digits = []
    while n:
        digits.append(n % base)
        n = n // base
    return digits[::-1]  # Reverse to get the correct order

def count_digit_occurrences(n, base):
    fact_n = factorial(n)
    digits = convert_to_base(fact_n, base)
    counter = Counter(digits)
    return counter

# Example usage:
base = 100
for i in range(1, 100):
    occurrence = count_digit_occurrences(i, base)
    subscript_digit = i
    result = occurrence.get(subscript_digit, 0)
    print(f"The digit {subscript_digit} appears {result} times in the factorial {i}! in base {base}")
# Out:
# The digit 1 appears 1 times in the factorial 1! in base 100
# The digit 2 appears 1 times in the factorial 2! in base 100
# The digit 3 appears 0 times in the factorial 3! in base 100
# The digit 4 appears 0 times in the factorial 4! in base 100
# The digit 5 appears 0 times in the factorial 5! in base 100
# The digit 6 appears 0 times in the factorial 6! in base 100
# The digit 7 appears 0 times in the factorial 7! in base 100
# The digit 8 appears 0 times in the factorial 8! in base 100
# The digit 9 appears 0 times in the factorial 9! in base 100
# The digit 10 appears 0 times in the factorial 10! in base 100
# The digit 11 appears 0 times in the factorial 11! in base 100
# The digit 12 appears 0 times in the factorial 12! in base 100
# The digit 13 appears 0 times in the factorial 13! in base 100
# The digit 14 appears 0 times in the factorial 14! in base 100
# The digit 15 appears 0 times in the factorial 15! in base 100
# The digit 16 appears 0 times in the factorial 16! in base 100
# The digit 17 appears 0 times in the factorial 17! in base 100
# The digit 18 appears 0 times in the factorial 18! in base 100
# The digit 19 appears 0 times in the factorial 19! in base 100
# The digit 20 appears 0 times in the factorial 20! in base 100
# The digit 21 appears 0 times in the factorial 21! in base 100
# The digit 22 appears 0 times in the factorial 22! in base 100
# The digit 23 appears 0 times in the factorial 23! in base 100
# The digit 24 appears 0 times in the factorial 24! in base 100
# The digit 25 appears 0 times in the factorial 25! in base 100
# The digit 26 appears 0 times in the factorial 26! in base 100
# The digit 27 appears 0 times in the factorial 27! in base 100
# The digit 28 appears 0 times in the factorial 28! in base 100
# The digit 29 appears 0 times in the factorial 29! in base 100
# The digit 30 appears 1 times in the factorial 30! in base 100
# The digit 31 appears 0 times in the factorial 31! in base 100
# The digit 32 appears 0 times in the factorial 32! in base 100
# The digit 33 appears 1 times in the factorial 33! in base 100
# The digit 34 appears 0 times in the factorial 34! in base 100
# The digit 35 appears 0 times in the factorial 35! in base 100
# The digit 36 appears 0 times in the factorial 36! in base 100
# The digit 37 appears 1 times in the factorial 37! in base 100
# The digit 38 appears 0 times in the factorial 38! in base 100
# The digit 39 appears 1 times in the factorial 39! in base 100
# The digit 40 appears 0 times in the factorial 40! in base 100
# The digit 41 appears 0 times in the factorial 41! in base 100
# The digit 42 appears 0 times in the factorial 42! in base 100
# The digit 43 appears 0 times in the factorial 43! in base 100
# The digit 44 appears 1 times in the factorial 44! in base 100
# The digit 45 appears 1 times in the factorial 45! in base 100
# The digit 46 appears 0 times in the factorial 46! in base 100
# The digit 47 appears 0 times in the factorial 47! in base 100
# The digit 48 appears 0 times in the factorial 48! in base 100
# The digit 49 appears 0 times in the factorial 49! in base 100
# The digit 50 appears 0 times in the factorial 50! in base 100
# The digit 51 appears 0 times in the factorial 51! in base 100
# The digit 52 appears 0 times in the factorial 52! in base 100
# The digit 53 appears 1 times in the factorial 53! in base 100
# The digit 54 appears 0 times in the factorial 54! in base 100
# The digit 55 appears 0 times in the factorial 55! in base 100
# The digit 56 appears 1 times in the factorial 56! in base 100
# The digit 57 appears 0 times in the factorial 57! in base 100
# The digit 58 appears 0 times in the factorial 58! in base 100
# The digit 59 appears 0 times in the factorial 59! in base 100
# The digit 60 appears 0 times in the factorial 60! in base 100
# The digit 61 appears 0 times in the factorial 61! in base 100
# The digit 62 appears 0 times in the factorial 62! in base 100
# The digit 63 appears 0 times in the factorial 63! in base 100
# The digit 64 appears 1 times in the factorial 64! in base 100
# The digit 65 appears 0 times in the factorial 65! in base 100
# The digit 66 appears 0 times in the factorial 66! in base 100
# The digit 67 appears 1 times in the factorial 67! in base 100
# The digit 68 appears 0 times in the factorial 68! in base 100
# The digit 69 appears 0 times in the factorial 69! in base 100
# The digit 70 appears 0 times in the factorial 70! in base 100
# The digit 71 appears 0 times in the factorial 71! in base 100
# The digit 72 appears 0 times in the factorial 72! in base 100
# The digit 73 appears 0 times in the factorial 73! in base 100
# The digit 74 appears 0 times in the factorial 74! in base 100
# The digit 75 appears 0 times in the factorial 75! in base 100
# The digit 76 appears 0 times in the factorial 76! in base 100
# The digit 77 appears 0 times in the factorial 77! in base 100
# The digit 78 appears 1 times in the factorial 78! in base 100
# The digit 79 appears 0 times in the factorial 79! in base 100
# The digit 80 appears 3 times in the factorial 80! in base 100
# The digit 81 appears 0 times in the factorial 81! in base 100
# The digit 82 appears 1 times in the factorial 82! in base 100
# The digit 83 appears 0 times in the factorial 83! in base 100
# The digit 84 appears 0 times in the factorial 84! in base 100
# The digit 85 appears 0 times in the factorial 85! in base 100
# The digit 86 appears 0 times in the factorial 86! in base 100
# The digit 87 appears 0 times in the factorial 87! in base 100
# The digit 88 appears 0 times in the factorial 88! in base 100
# The digit 89 appears 0 times in the factorial 89! in base 100
# The digit 90 appears 0 times in the factorial 90! in base 100
# The digit 91 appears 1 times in the factorial 91! in base 100
# The digit 92 appears 0 times in the factorial 92! in base 100
# The digit 93 appears 1 times in the factorial 93! in base 100
# The digit 94 appears 0 times in the factorial 94! in base 100
# The digit 95 appears 0 times in the factorial 95! in base 100
# The digit 96 appears 1 times in the factorial 96! in base 100
# The digit 97 appears 1 times in the factorial 97! in base 100
# The digit 98 appears 1 times in the factorial 98! in base 100
# The digit 99 appears 2 times in the factorial 99! in base 100

# %%
from ipywidgets import interact, IntSlider
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from collections import Counter

def factorial(n):
    if n == 0 or n == 1:
        return 1
    fact = 1
    for i in range(2, n + 1):
        fact *= i
    return fact

def convert_to_base(n, base):
    if n == 0:
        return [0]
    digits = []
    while n:
        digits.append(n % base)
        n = n // base
    return digits[::-1]

def count_digit_occurrences(n, base):
    fact_n = factorial(n)
    digits = convert_to_base(fact_n, base)
    counter = Counter(digits)
    return counter

def compute_occurrences(max_range, base):
    occurrences_matrix = np.zeros((max_range, base))
    for i in range(1, max_range + 1):
        occurrence = count_digit_occurrences(i, base)
        for digit in range(base):
            occurrences_matrix[i - 1, digit] = occurrence.get(digit, 0)
    return occurrences_matrix

def plot_occurrences(max_range, base):
    occurrences_matrix = compute_occurrences(max_range, base)
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    x_data, y_data = np.meshgrid(range(1, max_range + 1), range(base))
    x_data = x_data.flatten()
    y_data = y_data.flatten()
    z_data = occurrences_matrix.flatten()

    ax.bar3d(x_data, y_data, np.zeros_like(z_data), 1, 1, z_data, shade=True)

    ax.set_xlabel('Number (n)')
    ax.set_ylabel(f'Base-{base} Digit')
    ax.set_zlabel('Occurrences')

    plt.show()

def interactive_plot():
    interact(
        plot_occurrences,
        max_range=IntSlider(min=2, max=50, step=1, value=10, description='Max Range'),
        base=IntSlider(min=2, max=16, step=1, value=10, description='Base')
    )

# Run the interactive plot
interactive_plot()
# Out:
# interactive(children=(IntSlider(value=10, description='Max Range', max=50, min=2), IntSlider(value=10, descrip…

# %%
from collections import Counter
import sys

def factorial(n):
    if n < 0:
        print("Error: Factorial of negative numbers is undefined")
        sys.exit()
    elif n == 0 or n == 1:
        return 1
    fact = 1
    for i in range(2, n + 1):
        fact *= i
    return fact

def convert_to_base(n, base):
    if n == 0:
        return [0]
    digits = []
    while n:
        digits.append(n % base)
        n = n // base
    return digits[::-1]

def count_digit_occurrences(n, base):
    fact_n = factorial(n)
    digits = convert_to_base(fact_n, base)
    counter = Counter(digits)
    return counter

def calculate_product_occurrences(n1, n2, base):
    product_occurrences = Counter()
    for i in range(n1, n2 + 1):
        occurrence = count_digit_occurrences(i, base)
        for key, value in occurrence.items():
            product_occurrences[key] += value
    return product_occurrences

# Example usage:
base = 16
n1 = 10
n2 = 20
result = calculate_product_occurrences(n1, n2, base)
print(f"For the range {n1}-{n2}, the product of factorials has the following digit occurrences in base {base}:\n")
for key, value in result.items():
    print(f"The digit {key} appears {value} times")
# Out:
# For the range 10-20, the product of factorials has the following digit occurrences in base 16:
#
# The digit 3 appears 9 times
# The digit 7 appears 14 times
# The digit 5 appears 4 times
# The digit 15 appears 2 times
# The digit 0 appears 34 times
# The digit 2 appears 6 times
# The digit 6 appears 4 times
# The digit 1 appears 11 times
# The digit 12 appears 11 times
# The digit 8 appears 8 times
# The digit 4 appears 4 times
# The digit 11 appears 5 times
# The digit 14 appears 5 times
# The digit 13 appears 1 times
# The digit 10 appears 1 times
# The digit 9 appears 2 times
